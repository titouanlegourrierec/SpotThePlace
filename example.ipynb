# %% [markdown]
# ## Get streetview image of a specific location

# %%
from streetview import StreetViewScraper

# Example of how to use the StreetViewScraper class to get a streetview image of a specific location
scraper = StreetViewScraper(long=48.866667, lat=2.333333)
scraper.get_streetview_image()

# %% [markdown]
# ---
# ## Random points generation

# %%
from random_point_generator import RandomPointGenerator

generator = RandomPointGenerator()

# Example of how to use the RandomPointGenerator class to visualize random points on a map
country_points = generator.plot_points_in_country("Switzerland", 1000)

# To get the points as a GeoDataFrame
country_points = generator.generate_points_in_country("Switzerland", 1000)

country_points.head()
# Out:
#                     geometry       long        lat      country
# 0  POINT (10.31527 46.69357)  10.315271  46.693566  Switzerland
# 1   POINT (8.98478 45.98695)   8.984781  45.986954  Switzerland
# 2    POINT (7.5163 47.05509)   7.516299  47.055095  Switzerland
# 3   POINT (8.73326 46.11492)   8.733257  46.114923  Switzerland
# 4    POINT (8.3961 46.74341)   8.396100  46.743406  Switzerland
